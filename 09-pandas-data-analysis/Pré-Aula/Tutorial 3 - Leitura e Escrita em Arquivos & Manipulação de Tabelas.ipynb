# %% [markdown]
# # Tutorial 3: Leitura e Escrita em Arquivos & Manipulação de Tabelas

# %% [markdown]
# ___

# %% [markdown]
# # Imports para a Aula

# %%
import os
import pandas as pd

# %% [markdown]
# # Operações com Arquivos

# %% [markdown]
# ## Criando os Arquivos

# %% [markdown]
# ### Criando Estrutura de Pastas

# %%
try:
    os.makedirs("data")
    print("Pasta criada.")
except OSError:
    print("Pasta já existe!")
# Out:
# Pasta criada.

# %% [markdown]
# ### Dataset *orders.csv*

# %%
""" nome do arquivo """
file_name = os.path.join("data", "orders.csv")

# %%
""" criação do DataFrame """
df = pd.DataFrame(
    columns=["user_id", "store_id", "product_id"],
    data=[
        [1, 1, 1],
        [1, 2, 6],
        [3, 2, 7],
        [2, 2, 3],
        [3, 2, 3],
        [4, 3, 2],
        [2, 3, 1],
        [1, 1, 3],
        [1, 3, 3],
        [5, 1, 4],
        [5, 1, 1],
        [3, 2, 1],
        [1, 2, 1],
        [2, 2, 2],
        [3, 2, 2],
        [4, 2, 3],
        [4, 1, 5],
        [5, 1, 6],
        [3, 1, 6],
        [2, 3, 7],
    ]
)
df
# Out:
#     user_id  store_id  product_id
# 0         1         1           1
# 1         1         2           6
# 2         3         2           7
# 3         2         2           3
# 4         3         2           3
# 5         4         3           2
# 6         2         3           1
# 7         1         1           3
# 8         1         3           3
# 9         5         1           4
# 10        5         1           1
# 11        3         2           1
# 12        1         2           1
# 13        2         2           2
# 14        3         2           2
# 15        4         2           3
# 16        4         1           5
# 17        5         1           6
# 18        3         1           6
# 19        2         3           7

# %%
""" salvando o DataFrame """
df.to_csv(file_name, sep=",")

# %% [markdown]
# ### Dataset *stores.csv*

# %%
""" nome do arquivo """
file_name = os.path.join("data", "stores.csv")

# %%
""" criação do DataFrame """
df = pd.DataFrame(
    columns=["store_id", "store_name"],
    data=[
        [1, "Pão de Açúcar"],
        [2, "Dia"],
        [3, "Extra"],
    ]
).set_index("store_id")
df
# Out:
#              store_name
# store_id
# 1         Pão de Açúcar
# 2                   Dia
# 3                 Extra

# %%
""" salvando o DataFrame """
df.to_csv(
    file_name,          # nome do arquivo
    sep="\t",           # separador TAB
    encoding="utf-8"    # encoding: garante formato correto de strings no arquivo
)

# %% [markdown]
# ### Dataset *product.csv*

# %%
""" nome do arquivo """
file_name = os.path.join("data", "products.csv")

# %%
""" criação do DataFrame """
df = pd.DataFrame(
    columns=["product_id", "product_name"],
    data=[
        [1, "Leite"],
        [2, "Ovos"],
        [3, "Arroz"],
        [4, "Feijão"],
        [5, "Carne"],
        [6, "Frango"],
        [7, "Peixe"]
    ]
).set_index("product_id")  # set_index: usa a coluna especificada como índice
df
# Out:
#            product_name
# product_id
# 1                 Leite
# 2                  Ovos
# 3                 Arroz
# 4                Feijão
# 5                 Carne
# 6                Frango
# 7                 Peixe

# %%
""" salvando o DataFrame """
df.to_csv(
    file_name,          # nome do arquivo
    sep=";",            # separador ;
    encoding="utf-8"    # encoding: garante formato correto de strings no arquivo
)

# %% [markdown]
# ##  Leitura de Arquivos

# %% [markdown]
# ### Parâmetros _default_

# %%
file_name = os.path.join("data", "orders.csv")

# %%
pd.read_csv(file_name)
# Out:
#     Unnamed: 0  user_id  store_id  product_id
# 0            0        1         1           1
# 1            1        1         2           6
# 2            2        3         2           7
# 3            3        2         2           3
# 4            4        3         2           3
# 5            5        4         3           2
# 6            6        2         3           1
# 7            7        1         1           3
# 8            8        1         3           3
# 9            9        5         1           4
# 10          10        5         1           1
# 11          11        3         2           1
# 12          12        1         2           1
# 13          13        2         2           2
# 14          14        3         2           2
# 15          15        4         2           3
# 16          16        4         1           5
# 17          17        5         1           6
# 18          18        3         1           6
# 19          19        2         3           7

# %% [markdown]
# ### Parâmetro *index\_col*
# * define a coluna que contém o index
# * valores esperados: inteiro ou lista de inteiros
# * valor _default_: None

# %%
""" definindo index_col para a primeira coluna """
pd.read_csv(file_name, index_col=0)
# Out:
#     user_id  store_id  product_id
# 0         1         1           1
# 1         1         2           6
# 2         3         2           7
# 3         2         2           3
# 4         3         2           3
# 5         4         3           2
# 6         2         3           1
# 7         1         1           3
# 8         1         3           3
# 9         5         1           4
# 10        5         1           1
# 11        3         2           1
# 12        1         2           1
# 13        2         2           2
# 14        3         2           2
# 15        4         2           3
# 16        4         1           5
# 17        5         1           6
# 18        3         1           6
# 19        2         3           7

# %%
""" definindo index_col para a segunda coluna """
pd.read_csv(file_name, index_col=1)
# Out:
#          Unnamed: 0  store_id  product_id
# user_id
# 1                 0         1           1
# 1                 1         2           6
# 3                 2         2           7
# 2                 3         2           3
# 3                 4         2           3
# 4                 5         3           2
# 2                 6         3           1
# 1                 7         1           3
# 1                 8         3           3
# 5                 9         1           4
# 5                10         1           1
# 3                11         2           1
# 1                12         2           1
# 2                13         2           2
# 3                14         2           2
# 4                15         2           3
# 4                16         1           5
# 5                17         1           6
# 3                18         1           6
# 2                19         3           7

# %% [markdown]
# ###  Parâmetro _sep_
# * define o separador de colunas.
# * valores esperados: caractere
# * valor _default_: ","

# %%
""" Modificando o parâmetro sep"""
pd.read_csv(file_name, sep=";")
# Out:
#    ,user_id,store_id,product_id
# 0                       0,1,1,1
# 1                       1,1,2,6
# 2                       2,3,2,7
# 3                       3,2,2,3
# 4                       4,3,2,3
# 5                       5,4,3,2
# 6                       6,2,3,1
# 7                       7,1,1,3
# 8                       8,1,3,3
# 9                       9,5,1,4
# 10                     10,5,1,1
# 11                     11,3,2,1
# 12                     12,1,2,1
# 13                     13,2,2,2
# 14                     14,3,2,2
# 15                     15,4,2,3
# 16                     16,4,1,5
# 17                     17,5,1,6
# 18                     18,3,1,6
# 19                     19,2,3,7

# %%
""" Usando explicitamente o valor default de sep """
pd.read_csv(file_name, sep=",")
# Out:
#     Unnamed: 0  user_id  store_id  product_id
# 0            0        1         1           1
# 1            1        1         2           6
# 2            2        3         2           7
# 3            3        2         2           3
# 4            4        3         2           3
# 5            5        4         3           2
# 6            6        2         3           1
# 7            7        1         1           3
# 8            8        1         3           3
# 9            9        5         1           4
# 10          10        5         1           1
# 11          11        3         2           1
# 12          12        1         2           1
# 13          13        2         2           2
# 14          14        3         2           2
# 15          15        4         2           3
# 16          16        4         1           5
# 17          17        5         1           6
# 18          18        3         1           6
# 19          19        2         3           7

# %% [markdown]
# ###  Parâmetro _header_
# * define a linha que contém as colunas
# * valores esperados: inteiro ou lista de inteiros ou None
# * valor _default_: 0

# %%
""" Usando header = None """
pd.read_csv(file_name, header=None)
# Out:
#        0        1         2           3
# 0    NaN  user_id  store_id  product_id
# 1    0.0        1         1           1
# 2    1.0        1         2           6
# 3    2.0        3         2           7
# 4    3.0        2         2           3
# 5    4.0        3         2           3
# 6    5.0        4         3           2
# 7    6.0        2         3           1
# 8    7.0        1         1           3
# 9    8.0        1         3           3
# 10   9.0        5         1           4
# 11  10.0        5         1           1
# 12  11.0        3         2           1
# 13  12.0        1         2           1
# 14  13.0        2         2           2
# 15  14.0        3         2           2
# 16  15.0        4         2           3
# 17  16.0        4         1           5
# 18  17.0        5         1           6
# 19  18.0        3         1           6
# 20  19.0        2         3           7

# %%
""" Usando outra linha como header; nota-se que as linhas acima são eliminadas """
pd.read_csv(file_name, header=1)
# Out:
#      0  1  1.1  1.2
# 0    1  1    2    6
# 1    2  3    2    7
# 2    3  2    2    3
# 3    4  3    2    3
# 4    5  4    3    2
# 5    6  2    3    1
# 6    7  1    1    3
# 7    8  1    3    3
# 8    9  5    1    4
# 9   10  5    1    1
# 10  11  3    2    1
# 11  12  1    2    1
# 12  13  2    2    2
# 13  14  3    2    2
# 14  15  4    2    3
# 15  16  4    1    5
# 16  17  5    1    6
# 17  18  3    1    6
# 18  19  2    3    7

# %%
""" Usando múltiplass linhas como header """
pd.read_csv(file_name, header=[0,1,2])
# Out:
#    Unnamed: 0_level_0 user_id store_id product_id
#                     0       1        1          1
#                     1       1        2          6
# 0                   2       3        2          7
# 1                   3       2        2          3
# 2                   4       3        2          3
# 3                   5       4        3          2
# 4                   6       2        3          1
# 5                   7       1        1          3
# 6                   8       1        3          3
# 7                   9       5        1          4
# 8                  10       5        1          1
# 9                  11       3        2          1
# 10                 12       1        2          1
# 11                 13       2        2          2
# 12                 14       3        2          2
# 13                 15       4        2          3
# 14                 16       4        1          5
# 15                 17       5        1          6
# 16                 18       3        1          6
# 17                 19       2        3          7

# %% [markdown]
# ###  Parâmetro _usecols_
# * define quais colunas serão lidas, permitindo carregar apenas os dados desejados
# * valores esperados: lista de nomes ou None
# * valor _default_: None

# %%
""" lendo apenas duas colunas """
pd.read_csv(file_name, usecols=["product_id", "store_id"])
# Out:
#     store_id  product_id
# 0          1           1
# 1          2           6
# 2          2           7
# 3          2           3
# 4          2           3
# 5          3           2
# 6          3           1
# 7          1           3
# 8          3           3
# 9          1           4
# 10         1           1
# 11         2           1
# 12         2           1
# 13         2           2
# 14         2           2
# 15         2           3
# 16         1           5
# 17         1           6
# 18         1           6
# 19         3           7

# %% [markdown]
# #  Agrupando DataFrames

# %% [markdown]
# ## Carregando as Tabelas dos Arquivos

# %%
orders = pd.read_csv(
    os.path.join("data", "orders.csv"),
    sep=",",
    index_col=0
)

# %%
stores = pd.read_csv(
    os.path.join("data", "stores.csv"),
    sep="\t",
    index_col=0,
    encoding="utf-8"
)

# %%
products = pd.read_csv(
    os.path.join("data", "products.csv"),
    sep=";",
    index_col=0,
    encoding="utf-8"
)

# %% [markdown]
# ## Estruturas Homogêneas

# %% [markdown]
# ### Adicionando Linhas
# * método: _append_
# * concatena DataFrames no sentido das linhas

# %%
""" novos dados de 'orders' """
new_orders = pd.DataFrame(
    columns=["user_id", "store_id", "product_id"],
    data=[
        [1, 1, 1],
        [2, 1, 2],
        [3, 2, 1],
        [2, 1, 3],
        [1, 2, 1],
    ]
)

new_orders
# Out:
#    user_id  store_id  product_id
# 0        1         1           1
# 1        2         1           2
# 2        3         2           1
# 3        2         1           3
# 4        1         2           1

# %%
""" adicionando no 'orders' original """
temp_orders = orders.append(new_orders)

temp_orders
# Out:
#     user_id  store_id  product_id
# 0         1         1           1
# 1         1         2           6
# 2         3         2           7
# 3         2         2           3
# 4         3         2           3
# 5         4         3           2
# 6         2         3           1
# 7         1         1           3
# 8         1         3           3
# 9         5         1           4
# 10        5         1           1
# 11        3         2           1
# 12        1         2           1
# 13        2         2           2
# 14        3         2           2
# 15        4         2           3
# 16        4         1           5
# 17        5         1           6
# 18        3         1           6
# 19        2         3           7
# 0         1         1           1
# 1         2         1           2
# 2         3         2           1
# 3         2         1           3
# 4         1         2           1

# %% [markdown]
# Observações:
# * ***append*** não verifica índices, podendo repetir existentes
# * Caso um dos DataFrames tenha uma coluna a mais, o outro replica essa coluna, preenchida com NaNs

# %%
new_orders.append(
    pd.DataFrame(
        columns=list(new_orders.columns) + ["new_column"],
        data=[
            [1, 2, 1, 51],
            [1, 2, 1, 15]
        ]
    )
)
# Out:
#    new_column  product_id  store_id  user_id
# 0         NaN           1         1        1
# 1         NaN           2         1        2
# 2         NaN           1         2        3
# 3         NaN           3         1        2
# 4         NaN           1         2        1
# 0        51.0           1         2        1
# 1        15.0           1         2        1

# %% [markdown]
# ### Adicionando Colunas
# * método: _join_
# * concatena DataFrames no sentido das colunas
# * junta DataFrames usando como base o _index_

# %%
new_stores = pd.DataFrame(
    index=stores.index,
    columns=["opens", "closes"],    
    data=[
        ["9:00", "22:00"],
        ["8:00", "18:00"],
        ["11:00", "21:00"],
    ]
)
new_stores
# Out:
#           opens closes
# store_id
# 1          9:00  22:00
# 2          8:00  18:00
# 3         11:00  21:00

# %%
""" concatenando estruturas compatíveis  """
temp_stores = stores.join(new_stores)

temp_stores
# Out:
#              store_name  opens closes
# store_id
# 1         Pão de Açúcar   9:00  22:00
# 2                   Dia   8:00  18:00
# 3                 Extra  11:00  21:00

# %% [markdown]
# Observações:
# * Tipos de ***join***:
#     * inner
#     * outer
#     * left
#     * right
# * comportamento _default_: ***left join***

# %%
""" modificando índices para exemplos """
new_stores.index = [3, 4, 5]

# %%
""" concatenando estruturas com índices diferentes """
stores.join(new_stores)
# Out:
#              store_name opens closes
# store_id
# 1         Pão de Açúcar   NaN    NaN
# 2                   Dia   NaN    NaN
# 3                 Extra  9:00  22:00

# %%
""" explicitando 'how=left' """
stores.join(new_stores, how="left")
# Out:
#              store_name opens closes
# store_id
# 1         Pão de Açúcar   NaN    NaN
# 2                   Dia   NaN    NaN
# 3                 Extra  9:00  22:00

# %%
""" right join """
stores.join(new_stores, how="right")
# Out:
#   store_name  opens closes
# 3      Extra   9:00  22:00
# 4        NaN   8:00  18:00
# 5        NaN  11:00  21:00

# %%
""" concatenando estruturas com índices diferentes """
stores.join(new_stores, how="outer")
# Out:
#       store_name  opens closes
# 1  Pão de Açúcar    NaN    NaN
# 2            Dia    NaN    NaN
# 3          Extra   9:00  22:00
# 4            NaN   8:00  18:00
# 5            NaN  11:00  21:00

# %%
""" concatenando estruturas com índices diferentes """
stores.join(new_stores, how="inner")
# Out:
#   store_name opens closes
# 3      Extra  9:00  22:00

# %% [markdown]
# #### Observação:
# Em DataFrames com nomes de coluna iguais, deve-se especificar sufixos para diferenciar as colunas.

# %%
new_stores.join(new_stores, lsuffix="_original")
# Out:
#   opens_original closes_original  opens closes
# 3           9:00           22:00   9:00  22:00
# 4           8:00           18:00   8:00  18:00
# 5          11:00           21:00  11:00  21:00

# %%
new_stores.join(new_stores, rsuffix="_copycat")
# Out:
#    opens closes opens_copycat closes_copycat
# 3   9:00  22:00          9:00          22:00
# 4   8:00  18:00          8:00          18:00
# 5  11:00  21:00         11:00          21:00

# %%
new_stores.join(new_stores, lsuffix="_original", rsuffix="_copycat")
# Out:
#   opens_original closes_original opens_copycat closes_copycat
# 3           9:00           22:00          9:00          22:00
# 4           8:00           18:00          8:00          18:00
# 5          11:00           21:00         11:00          21:00

# %% [markdown]
# ## Estruturas Heterogêneas
# * método _merge_
# * construção de tabelas que compartilham uma ou mais variáveis
# * sufixos: idêntico a _join_
# * todos os tipos de join (inner, outer, left e right) são suportados
# * simplificando: _join_ onde se escolhe uma coluna em vez do index

# %%
""" reset_index para liberar as variáveis para o merge """
stores = stores.reset_index()
products = products.reset_index()

# %%
""" adicionando store_name"""
df = pd.merge(
    left=orders,
    right=stores,
    on="store_id"
)
df
# Out:
#     user_id  store_id  product_id     store_name
# 0         1         1           1  Pão de Açúcar
# 1         1         1           3  Pão de Açúcar
# 2         5         1           4  Pão de Açúcar
# 3         5         1           1  Pão de Açúcar
# 4         4         1           5  Pão de Açúcar
# 5         5         1           6  Pão de Açúcar
# 6         3         1           6  Pão de Açúcar
# 7         1         2           6            Dia
# 8         3         2           7            Dia
# 9         2         2           3            Dia
# 10        3         2           3            Dia
# 11        3         2           1            Dia
# 12        1         2           1            Dia
# 13        2         2           2            Dia
# 14        3         2           2            Dia
# 15        4         2           3            Dia
# 16        4         3           2          Extra
# 17        2         3           1          Extra
# 18        1         3           3          Extra
# 19        2         3           7          Extra

# %%
""" adicionando product_name"""
df = pd.merge(
    left=df,
    right=products,
    on="product_id"
)
df
# Out:
#     user_id  store_id  product_id     store_name product_name
# 0         1         1           1  Pão de Açúcar        Leite
# 1         5         1           1  Pão de Açúcar        Leite
# 2         3         2           1            Dia        Leite
# 3         1         2           1            Dia        Leite
# 4         2         3           1          Extra        Leite
# 5         1         1           3  Pão de Açúcar        Arroz
# 6         2         2           3            Dia        Arroz
# 7         3         2           3            Dia        Arroz
# 8         4         2           3            Dia        Arroz
# 9         1         3           3          Extra        Arroz
# 10        5         1           4  Pão de Açúcar       Feijão
# 11        4         1           5  Pão de Açúcar        Carne
# 12        5         1           6  Pão de Açúcar       Frango
# 13        3         1           6  Pão de Açúcar       Frango
# 14        1         2           6            Dia       Frango
# 15        3         2           7            Dia        Peixe
# 16        2         3           7          Extra        Peixe
# 17        2         2           2            Dia         Ovos
# 18        3         2           2            Dia         Ovos
# 19        4         3           2          Extra         Ovos
